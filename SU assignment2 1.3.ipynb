# %%
# !pip install speechbrain
# !pip install museval
# !pip install pesq
# !pip install mir_eval
# Out:
# Collecting speechbrain
#   Downloading speechbrain-1.0.2-py3-none-any.whl.metadata (23 kB)
# Collecting hyperpyyaml (from speechbrain)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.4.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from speechbrain) (24.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.13.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from speechbrain) (0.2.0)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.5.1+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.5.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from speechbrain) (4.67.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from speechbrain) (0.29.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.9->speechbrain) (1.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (2.32.3)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->speechbrain) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->speechbrain) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->speechbrain) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->speechbrain) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->speechbrain) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->speechbrain) (2.4.1)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->speechbrain) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->speechbrain) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->speechbrain) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->speechbrain) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->speechbrain) (2024.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (2025.1.31)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->speechbrain) (2024.2.0)
# Downloading speechbrain-1.0.2-py3-none-any.whl (824 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.8/824.8 kB 17.9 MB/s eta 0:00:0000:01
# Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 7.6 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (722 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 722.2/722.2 kB 37.9 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, hyperpyyaml, speechbrain
# Successfully installed hyperpyyaml-1.2.2 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 speechbrain-1.0.2
# Collecting museval
#   Downloading museval-0.4.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting musdb>=0.4.0 (from museval)
#   Downloading musdb-0.4.2-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from museval) (2.2.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from museval) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from museval) (1.13.1)
# Collecting simplejson>=3.19.0 (from museval)
#   Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (from museval) (0.12.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from museval) (4.23.0)
# Collecting stempeg>=0.2.3 (from musdb>=0.4.0->museval)
#   Downloading stempeg-0.2.3-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pyaml in /usr/local/lib/python3.10/dist-packages (from musdb>=0.4.0->museval) (25.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from musdb>=0.4.0->museval) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy->museval) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy->museval) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy->museval) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy->museval) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy->museval) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy->museval) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->museval) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->museval) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->museval) (2025.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->museval) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->museval) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->museval) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->museval) (0.22.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile->museval) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile->museval) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->museval) (1.17.0)
# Collecting ffmpeg-python>=0.2.0 (from stempeg>=0.2.3->musdb>=0.4.0->museval)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->museval) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy->museval) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy->museval) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy->museval) (2024.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml->musdb>=0.4.0->museval) (6.0.2)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from ffmpeg-python>=0.2.0->stempeg>=0.2.3->musdb>=0.4.0->museval) (1.0.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy->museval) (2024.2.0)
# Downloading museval-0.4.1-py2.py3-none-any.whl (20 kB)
# Downloading musdb-0.4.2-py2.py3-none-any.whl (13 kB)
# Downloading simplejson-3.20.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 5.5 MB/s eta 0:00:00
# Downloading stempeg-0.2.3-py3-none-any.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 29.0 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Installing collected packages: simplejson, ffmpeg-python, stempeg, musdb, museval
# Successfully installed ffmpeg-python-0.2.0 musdb-0.4.2 museval-0.4.1 simplejson-3.20.1 stempeg-0.2.3
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pesq
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp310-cp310-linux_x86_64.whl size=262950 sha256=60c75888f0623be35db0865dd2ce31dad8c72726fabe62a3449d6b952b003fcc
#   Stored in directory: /root/.cache/pip/wheels/c5/4e/2c/251524370c0fdd659e99639a0fbd0ca5a782c3aafcd456b28d
# Successfully built pesq
# Installing collected packages: pesq
# Successfully installed pesq-0.0.4
# Collecting mir_eval
#   Downloading mir_eval-0.8.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.10/dist-packages (from mir_eval) (1.26.4)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mir_eval) (1.13.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mir_eval) (4.4.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.15.4->mir_eval) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.15.4->mir_eval) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.15.4->mir_eval) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.15.4->mir_eval) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.15.4->mir_eval) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.15.4->mir_eval) (2024.2.0)
# Downloading mir_eval-0.8.2-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: mir_eval
# Successfully installed mir_eval-0.8.2

# %%
import os
import torch
import torchaudio
import librosa
import numpy as np
import pandas as pd
from speechbrain.inference.separation import SepformerSeparation as separator
from pesq import pesq
from tqdm import tqdm
import torch
from transformers import WavLMModel, WavLMForXVector
from sklearn.metrics.pairwise import cosine_similarity
import torch.nn as nn
from peft import LoraConfig, get_peft_model

# %%
device_env = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device_env}")
# Out:
# Using device: cuda

# %%
from speechbrain.inference.separation import SepformerSeparation as SepFormerModel

sepformer_model = SepFormerModel.from_hparams(
    source="speechbrain/sepformer-whamr", 
    savedir='pretrained_models/sepformer-whamr',
    run_opts={"device":"cuda"}
).to(device_env)
# Out:
# hyperparams.yaml:   0%|          | 0.00/1.51k [00:00<?, ?B/s]
# masknet.ckpt:   0%|          | 0.00/113M [00:00<?, ?B/s]
# encoder.ckpt:   0%|          | 0.00/17.3k [00:00<?, ?B/s]
# decoder.ckpt:   0%|          | 0.00/17.3k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/speechbrain/utils/checkpoints.py:200: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)

# %%
import os
import torchaudio
import librosa
import numpy as np
import mir_eval
from tqdm import tqdm

source_audio_dir = '/kaggle/input/vow-2-test/aac'
train_mix_dir = '/kaggle/working/mixed_train'
test_mix_dir = '/kaggle/working/mixed_test'
sep_output_dir = '/kaggle/working/sepformer_output'

device_env = "cuda" if torch.cuda.is_available() else "cpu"
sep_model = SepFormerModel.from_hparams(
    source="speechbrain/sepformer-whamr", 
    savedir='pretrained_models/sepformer-whamr',
    run_opts={"device": "cuda"}
)

# %%
def calculate_metrics(ref_signal, est_signal):
    ref_signal = np.atleast_2d(ref_signal)
    est_signal = np.atleast_2d(est_signal)
    if ref_signal.shape[1] != est_signal.shape[1]:
        raise ValueError(f"Shape mismatch: ref_signal {ref_signal.shape}, est_signal {est_signal.shape}")
    sdr_val, sir_val, sar_val, _ = mir_eval.separation.bss_eval_sources(ref_signal, est_signal)
    return sdr_val[0], sir_val[0], sar_val[0]

def get_m4a_files(root_folder):
    file_list = []
    for current_root, _, files in os.walk(root_folder):
        for item in files:
            if item.endswith('.m4a'):
                file_list.append(os.path.join(current_root, item))
    return file_list

def create_mixed_audio(path_id1, path_id2, mix_output_dir):
    files_first = get_m4a_files(path_id1)
    files_second = get_m4a_files(path_id2)
    
    if not files_first or not files_second:
        print(f"Skipping pair {path_id1}, {path_id2} (missing valid audio files)")
        return None, None, None
    
    selected_file1 = np.random.choice(files_first)
    selected_file2 = np.random.choice(files_second)

    audio_signal1, sample_rate1 = torchaudio.load(selected_file1)
    audio_signal2, sample_rate2 = torchaudio.load(selected_file2)

    resample_transform = torchaudio.transforms.Resample(orig_freq=sample_rate1, new_freq=8000)
    audio_signal1 = resample_transform(audio_signal1) if sample_rate1 != 8000 else audio_signal1
    audio_signal2 = resample_transform(audio_signal2) if sample_rate2 != 8000 else audio_signal2

    audio_signal1 = audio_signal1.mean(dim=0) if audio_signal1.shape[0] > 1 else audio_signal1.squeeze(0)
    audio_signal2 = audio_signal2.mean(dim=0) if audio_signal2.shape[0] > 1 else audio_signal2.squeeze(0)

    common_length = min(audio_signal1.shape[0], audio_signal2.shape[0])
    audio_signal1, audio_signal2 = audio_signal1[:common_length], audio_signal2[:common_length]

    combined_signal = audio_signal1 + audio_signal2
    combined_signal = combined_signal / torch.max(torch.abs(combined_signal))

    os.makedirs(mix_output_dir, exist_ok=True)
    mix_filename = os.path.join(mix_output_dir, f'{os.path.basename(selected_file1).split(".")[0]}_{os.path.basename(selected_file2).split(".")[0]}.wav')
    combined_signal = combined_signal.unsqueeze(0)
    torchaudio.save(mix_filename, combined_signal, 8000)
    return mix_filename, selected_file1, selected_file2

# %%
# !rm -rf /kaggle/working/mixed_train

test_mix_dir = "/kaggle/working/mixtures"
mix_dictionary = {}  

audio_ids = sorted(os.listdir(source_audio_dir))[50:]
for idx in range(0, len(audio_ids) - 1, 2):
    folder1 = os.path.join(source_audio_dir, audio_ids[idx])
    folder2 = os.path.join(source_audio_dir, audio_ids[idx + 1])
    mix_path, orig_file1, orig_file2 = create_mixed_audio(folder1, folder2, test_mix_dir)
    print(mix_path)
    if mix_path:
        mix_dictionary[mix_path] = (orig_file1, orig_file2)
norm_mix_dictionary = {os.path.abspath(k): v for k, v in mix_dictionary.items()}
# Out:
# /kaggle/working/mixtures/00030_00339.wav
# /kaggle/working/mixtures/00285_00052.wav
# /kaggle/working/mixtures/00021_00059.wav
# /kaggle/working/mixtures/00090_00019.wav
# /kaggle/working/mixtures/00240_00056.wav
# /kaggle/working/mixtures/00007_00058.wav
# /kaggle/working/mixtures/00420_00147.wav
# /kaggle/working/mixtures/00184_00249.wav
# /kaggle/working/mixtures/00091_00375.wav
# /kaggle/working/mixtures/00454_00021.wav
# /kaggle/working/mixtures/00022_00402.wav
# /kaggle/working/mixtures/00245_00189.wav
# /kaggle/working/mixtures/00216_00153.wav
# /kaggle/working/mixtures/00150_00342.wav
# /kaggle/working/mixtures/00019_00134.wav
# /kaggle/working/mixtures/00331_00200.wav
# /kaggle/working/mixtures/00012_00002.wav
# /kaggle/working/mixtures/00152_00037.wav
# /kaggle/working/mixtures/00148_00196.wav
# /kaggle/working/mixtures/00112_00115.wav
# /kaggle/working/mixtures/00199_00481.wav
# /kaggle/working/mixtures/00050_00146.wav
# /kaggle/working/mixtures/00092_00096.wav
# /kaggle/working/mixtures/00299_00015.wav
# /kaggle/working/mixtures/00066_00147.wav
# /kaggle/working/mixtures/00103_00065.wav
# /kaggle/working/mixtures/00332_00215.wav
# /kaggle/working/mixtures/00291_00107.wav
# /kaggle/working/mixtures/00297_00214.wav
# /kaggle/working/mixtures/00016_00377.wav
# /kaggle/working/mixtures/00269_00413.wav
# /kaggle/working/mixtures/00054_00268.wav
# /kaggle/working/mixtures/00306_00046.wav
# /kaggle/working/mixtures/00024_00211.wav

# %%
import warnings
warnings.filterwarnings("ignore")

os.makedirs(sep_output_dir, exist_ok=True)

accumulated_sdr, accumulated_sir, accumulated_sar, accumulated_pesq = 0, 0, 0, 0
file_count = 0

def process_and_assess(mixed_filepath):
    global accumulated_sdr, accumulated_sir, accumulated_sar, accumulated_pesq, file_count

    abs_mixed_filepath = os.path.abspath(mixed_filepath)
    
    if abs_mixed_filepath not in norm_mix_dictionary:
        print(f"Warning: Missing key for file: {abs_mixed_filepath}")
        print("Available keys (first 5):", list(norm_mix_dictionary.keys())[:5])
        return None 
    mix_wave, fs = torchaudio.load(mixed_filepath)
    resample_fs = torchaudio.transforms.Resample(orig_freq=fs, new_freq=8000)
    mix_wave = resample_fs(mix_wave) if fs != 8000 else mix_wave

    separated_output = sep_model.separate_batch(mix_wave.to(device_env))
    separated_np = separated_output.cpu().squeeze(0).numpy()

    base_filename = os.path.basename(mixed_filepath).split(".")[0]
    
    orig_path1, orig_path2 = norm_mix_dictionary[abs_mixed_filepath]
    
    if orig_path1 and orig_path2:
        ref_wave1, _ = librosa.load(orig_path1, sr=8000)
        ref_wave2, _ = librosa.load(orig_path2, sr=8000)
        common_samples = min(len(ref_wave1), len(ref_wave2))
        ref_wave1, ref_wave2 = ref_wave1[:common_samples], ref_wave2[:common_samples]
        est_wave1 = separated_np[:, 0]
        est_wave2 = separated_np[:, 1]
        reference_stack = np.stack((ref_wave1, ref_wave2), axis=0)

        sdr_val, sir_val, sar_val = calculate_metrics(reference_stack, separated_np.T)
        pesq_val1 = pesq(8000, ref_wave1, est_wave1, mode='nb')
        pesq_val2 = pesq(8000, ref_wave2, est_wave2, mode='nb')

        accumulated_sdr += sdr_val
        accumulated_sir += sir_val
        accumulated_sar += sar_val
        accumulated_pesq += (pesq_val1 + pesq_val2)
        file_count += 1

    out_path1 = os.path.join(sep_output_dir, base_filename + "_spk1.wav")
    out_path2 = os.path.join(sep_output_dir, base_filename + "_spk2.wav")
    torchaudio.save(out_path1, torch.tensor(separated_np[0]).unsqueeze(0), 8000)
    torchaudio.save(out_path2, torch.tensor(separated_np[1]).unsqueeze(0), 8000)

    return out_path1, out_path2

# %%
accumulated_sdr, accumulated_sir, accumulated_sar, accumulated_pesq = 0, 0, 0, 0
file_count = 0

print("processed")
mixed_files_list = [os.path.join(test_mix_dir, f) for f in os.listdir(test_mix_dir)]
for mix_file in tqdm(mixed_files_list):
    process_and_assess(mix_file)
# Out:
# processed
#   1%|          | 1/170 [00:00<02:08,  1.32it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00455_00074.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00016_00360.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00052_00208.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#   4%|▎         | 6/170 [00:02<01:22,  1.98it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00099_00040.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#   5%|▍         | 8/170 [00:04<01:23,  1.94it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00127_00083.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00060_00020.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#   6%|▋         | 11/170 [00:04<01:03,  2.51it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00005_00134.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00437_00164.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00213_00117.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00037_00156.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00076_00010.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00133_00377.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  11%|█         | 18/170 [00:05<00:34,  4.36it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00370_00250.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00273_00219.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00467_00015.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00452_00052.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  14%|█▎        | 23/170 [00:06<00:29,  5.02it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00288_00154.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00040_00234.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  15%|█▌        | 26/170 [00:07<00:29,  4.82it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00311_00488.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  16%|█▋        | 28/170 [00:07<00:35,  4.01it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00320_00004.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00009_00257.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00444_00135.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00101_00199.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00032_00061.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00210_00101.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00169_00486.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00030_00226.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00042_00028.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00210_00329.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00057_00051.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00404_00052.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00025_00001.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00490_00201.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  26%|██▌       | 44/170 [00:09<00:18,  6.92it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00124_00007.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00183_00029.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00132_00007.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00162_00199.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00271_00406.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00385_00181.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00096_00002.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00380_00030.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00289_00395.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00307_00223.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  34%|███▎      | 57/170 [00:11<00:21,  5.23it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00033_00308.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00330_00286.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00003_00185.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00227_00234.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  36%|███▋      | 62/170 [00:12<00:22,  4.82it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00151_00035.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00149_00014.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00459_00102.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00309_00484.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  39%|███▉      | 67/170 [00:13<00:18,  5.44it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00173_00215.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00026_00121.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  41%|████      | 70/170 [00:14<00:20,  4.89it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00078_00086.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00019_00013.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00098_00174.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00300_00048.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00320_00051.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00056_00033.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00098_00004.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00024_00012.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00350_00332.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00034_00206.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00116_00124.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00060_00283.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00115_00066.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00156_00209.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00117_00194.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00332_00298.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00247_00043.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00071_00289.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00109_00002.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00035_00021.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00141_00240.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  54%|█████▍    | 92/170 [00:14<00:06, 11.99it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00267_00476.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00012_00270.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00203_00186.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  56%|█████▋    | 96/170 [00:15<00:07,  9.76it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00203_00316.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  58%|█████▊    | 98/170 [00:16<00:10,  7.06it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00399_00480.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  59%|█████▉    | 100/170 [00:17<00:12,  5.75it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00065_00103.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00403_00205.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  61%|██████    | 103/170 [00:18<00:14,  4.78it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00068_00074.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00214_00006.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00053_00050.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00181_00116.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00204_00261.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00121_00004.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00064_00163.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00272_00008.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00193_00194.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  66%|██████▋   | 113/170 [00:19<00:08,  7.02it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00479_00149.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00016_00172.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00060_00318.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00224_00171.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  70%|███████   | 119/170 [00:21<00:10,  5.02it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00003_00437.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00003_00040.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00464_00094.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00451_00058.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00061_00498.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00163_00072.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00015_00370.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00026_00269.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00079_00214.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00190_00114.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00480_00105.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  77%|███████▋  | 131/170 [00:21<00:04,  7.96it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00146_00170.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00432_00409.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00136_00106.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  79%|███████▉  | 135/170 [00:22<00:04,  7.50it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00123_00048.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00404_00234.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00137_00475.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00179_00385.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00306_00182.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00306_00018.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00046_00274.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  84%|████████▍ | 143/170 [00:23<00:03,  7.15it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00064_00087.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  86%|████████▌ | 146/170 [00:25<00:05,  4.26it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00041_00007.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00026_00024.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  88%|████████▊ | 149/170 [00:26<00:05,  3.77it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00223_00079.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00168_00185.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00256_00010.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00373_00135.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00019_00079.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00201_00285.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
#  92%|█████████▏| 156/170 [00:27<00:02,  5.00it/s]
# Warning: Missing key for file: /kaggle/working/mixtures/00063_00012.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00133_00004.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00089_00073.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00054_00257.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00086_00068.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00245_00048.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00241_00006.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00369_00198.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00225_00131.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00054_00133.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00006_00165.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# Warning: Missing key for file: /kaggle/working/mixtures/00186_00298.wav
# Available keys (first 5): ['/kaggle/working/mixtures/00030_00339.wav', '/kaggle/working/mixtures/00285_00052.wav', '/kaggle/working/mixtures/00021_00059.wav', '/kaggle/working/mixtures/00090_00019.wav', '/kaggle/working/mixtures/00240_00056.wav']
# 100%|██████████| 170/170 [00:28<00:00,  5.92it/s]

# %%
print("\nAverage Evaluation Metrics:")
print(f"Average SDR: {accumulated_sdr / file_count:.2f}")
print(f"Average SIR: {accumulated_sir / file_count:.2f}")
print(f"Average SAR: {accumulated_sar / file_count:.2f}")
print(f"Average PESQ: {accumulated_pesq / (2 * file_count):.2f}")
# Out:
# Average Evaluation Metrics:
# Average SDR: 3.25
# Average SIR: 15.98
# Average SAR: 5.63
# Average PESQ: 1.62

# %%
from sklearn.metrics import accuracy_score

def obtain_speaker_embedding(model_obj, audio_path):
    waveform_data, _ = torchaudio.load(audio_path)
    waveform_data = waveform_data.to(device_env)
    with torch.no_grad():
        embedding_out = model_obj(waveform_data).last_hidden_state.mean(dim=1)
    return embedding_out.cpu().numpy()

actual_labels, predicted_labels_pre, predicted_labels_finetuned = [], [], []
for folder in tqdm(os.listdir(sep_output_dir), desc="Evaluating Speaker Identification"):
    folder_path = os.path.join(sep_output_dir, folder)
    if not os.path.isdir(folder_path):
        continue

    spk_label1, spk_label2 = folder.split("_")[:2]
    actual_labels += [spk_label1, spk_label2]

    audio_spk1 = os.path.join(folder_path, f"speaker1.wav")
    audio_spk2 = os.path.join(folder_path, f"speaker2.wav")
    print(audio_spk1)
    emb_pre1 = obtain_speaker_embedding(wavlm_pretrained, audio_spk1)
    emb_pre2 = obtain_speaker_embedding(wavlm_pretrained, audio_spk2)
    emb_fine1 = obtain_speaker_embedding(speaker_classifier, audio_spk1)
    emb_fine2 = obtain_speaker_embedding(speaker_classifier, audio_spk2)

    predicted_labels_pre += [f"id{np.argmax(emb_pre1)}", f"id{np.argmax(emb_pre2)}"]
    predicted_labels_finetuned += [f"id{np.argmax(emb_fine1)}", f"id{np.argmax(emb_fine2)}"]
# Out:
# Evaluating Speaker Identification: 100%|██████████| 68/68 [00:00<00:00, 57735.36it/s]

# %%
fine_tuned_wavlm = WavLMForXVector.from_pretrained("microsoft/wavlm-base-plus").to(device_env)
fine_tuned_model_path = "/kaggle/input/fine-tuned-wavlm-model/fine_tuned_wavlm.pth"
fine_tuned_wavlm.load_state_dict(torch.load(fine_tuned_model_path, map_location=device_env))

# %%
wavlm_model = WavLMForXVector.from_pretrained("microsoft/wavlm-base-plus").to(device_env)
wavlm_model.load_state_dict(torch.load(model_path, map_location=device_env))

# %%
sep_output_dir = "/kaggle/working/sepformer_output"

def extract_speaker_embedding(audio_path):
    waveform, sample_rate = torchaudio.load(audio_path)
    if sample_rate != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)
        waveform = resampler(waveform)
    waveform = waveform.mean(dim=0).unsqueeze(0)

    with torch.no_grad():
        embedding = wavlm_model(waveform.to(device_env)).embeddings.cpu().numpy()
    return embedding

separated_files = sorted([f for f in os.listdir(sep_output_dir) if f.endswith(".wav")])
num_correct = 0
total_speakers = len(separated_files) // 2

reference_embeddings = {}


for mix_file, (orig_file1, orig_file2) in norm_mix_dictionary.items():
    ref_embedding1 = extract_speaker_embedding(orig_file1)
    ref_embedding2 = extract_speaker_embedding(orig_file2)
    reference_embeddings[orig_file1] = ref_embedding1
    reference_embeddings[orig_file2] = ref_embedding2

for sep_file in separated_files:
    sep_path = os.path.join(sep_output_dir, sep_file)
    sep_embedding = extract_speaker_embedding(sep_path)

    best_match = None
    best_score = -1

    for ref_path, ref_embedding in reference_embeddings.items():
        score = cosine_similarity(sep_embedding, ref_embedding)[0, 0]
        if score > best_score:
            best_score = score
            best_match = ref_path

    if best_match in norm_mix_dictionary[os.path.abspath(sep_path)]:
        num_correct += 1

# %%
rank1_pretrained = compute_rank1_accuracy(pretrained_wavlm)
rank1_finetuned = compute_rank1_accuracy(fine_tuned_wavlm)

print("\nRank-1 Speaker Identification Accuracy:")
print(f"Pre-trained WavLM: {rank1_pretrained * 100:.2f}%")
print(f"Fine-tuned WavLM: {rank1_finetuned * 100:.2f}%")
# Out:
# Rank-1 Speaker Identification Accuracy:
# Pre-trained WavLM: 16.17%
# Fine-tuned WavLM: 26.47%
